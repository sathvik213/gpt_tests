# %% [markdown]
# # Import open ai

# %%
pip install openai
# Out:
# ...
#   Using cached openai-0.20.0.tar.gz (42 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Using cached pandas_stubs-1.4.2.220626-py3-none-any.whl (123 kB)
# ...
#   Created wheel for openai: filename=openai-0.20.0-py3-none-any.whl size=54094 sha256=b43f2a0ee54c6117c27cdd38aa1246230cb26018f49814b2256296fd89d51fc8
#   Stored in directory: c:\users\sathvik\appdata\local\pip\cache\wheels\42\bd\1d\f1d7e85562515ca1b9504a9450c89623329c0e24af7c749dc6
# Successfully built openai
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ygments (c:\python310\lib\site-packages)
# ...

# %%
import openai
import json

# %% [markdown]
# # setup api key

# %%
API_KEY="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"
openai.api_key=API_KEY

# %% [markdown]
# # Declaring prompt

# %%
prompt_text="what kind of treatments are available for cancer cure,which of them do you think is the better solution? "

# %% [markdown]
# # Response generation

# %%
response = openai.Completion.create(
  model="text-davinci-001",
  prompt=prompt_text,
max_tokens=100)

# %%
response['choices']
# Out:
# [<OpenAIObject at 0x17072205da0> JSON: {
#    "finish_reason": "stop",
#    "index": 0,
#    "logprobs": null,
#    "text": "\n\nThere are many treatments available for cancer cure. However, the best solution is to prevent cancer."
#  }]

# %%
response_2 = openai.Completion.create(
  model="text-davinci-001",
  prompt=prompt_text,
max_tokens=1000)

# %%
print(response_2['choices'])
# Out:
# [<OpenAIObject at 0x17071e2db20> JSON: {
#   "finish_reason": "stop",
#   "index": 0,
#   "logprobs": null,
#   "text": "\n\nThere are a variety of cancer treatments available, including radiation therapy, chemotherapy, and surgery. There is no one definitive answer as to which is the best solution."
# }]

# %% [markdown]
# # Testing with 'text-davinci-002'

# %%
prompt_text_2="what are the types of lung cancer? What are its symptoms?"
response_3=openai.Completion.create(
  model="text-davinci-002",
  prompt=prompt_text_2,
max_tokens=1000)

# %%
file=response_3['choices']
file
# Out:
# [<OpenAIObject at 0x17072d5eca0> JSON: {
#    "finish_reason": "stop",
#    "index": 0,
#    "logprobs": null,
#    "text": "\n\nThere are several types of lung cancer, the most common being non-small cell lung cancer and small cell lung cancer. Symptoms of lung cancer include a cough that does not go away, shortness of breath, chest pain, and wheezing."
#  }]
